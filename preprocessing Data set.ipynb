# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\BRAKAY\Desktop\data science\Data_Set.csv",header = 2)
data.head(5)
# Out:
#    Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0     1    24.0      28    10          -15             12
# 1     2    17.0      32    12          -17             12
# 2     3    16.0      34    11          -19             12
# 3     3    16.0      34    11          -19             12
# 4     4    16.0      33    12          -18             12

# %%
data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0      1    24.0      28    10          -15             12
# 1      2    17.0      32    12          -17             12
# 2      3    16.0      34    11          -19             12
# 3      3    16.0      34    11          -19             12
# 4      4    16.0      33    12          -18             12
# 5      5    16.0      30    10          -14             12
# 6      6    16.0      31    10          -16             12
# 7      7    19.0      28    14          -14             12
# 8      8    22.0      29    12          -15              9
# 9      9    25.0      26    12          -12              8
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14     NaN      13    17            2              4
# ...

# %%
data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0      1    24.0      28    10          -15             12
# 1      2    17.0      32    12          -17             12
# 2      3    16.0      34    11          -19             12
# 3      3    16.0      34    11          -19             12
# 4      4    16.0      33    12          -18             12
# 5      5    16.0      30    10          -14             12
# 6      6    16.0      31    10          -16             12
# 7      7    19.0      28    14          -14             12
# 8      8    22.0      29    12          -15              9
# 9      9    25.0      26    12          -12              8
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14     NaN      13    17            2              4
# ...

# %%
data.isnull().sum()
# Out:
# Time             0
# E_Plug           1
# E_Heat           0
# Price            0
# Temperature      0
# No. Occupants    0
# dtype: int64

# %%
data.fillna(method = 'ffill',inplace = True)

# %%
data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0      1    24.0      28    10          -15             12
# 1      2    17.0      32    12          -17             12
# 2      3    16.0      34    11          -19             12
# 3      3    16.0      34    11          -19             12
# 4      4    16.0      33    12          -18             12
# 5      5    16.0      30    10          -14             12
# 6      6    16.0      31    10          -16             12
# 7      7    19.0      28    14          -14             12
# 8      8    22.0      29    12          -15              9
# 9      9    25.0      26    12          -12              8
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14    30.0      13    17            2              4
# ...

# %%
data

# %%
data['Price'] = pd.to_numeric(data['Price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-d65aea6270a0> in <module>
# ----> 1 data['Price'] = pd.to_numeric(data['Price'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data.shape

# %%
data.drop(['No. Occupants'],axis=1, inplace = True)

# %%
data.drop(2,axis = 0, inplace =True)

# %%
data.head()

# %%
dataset = data.describe()
dataset

# %%
file  = dataset['E_Heat'].min()
file

# %%
dataset['E_Heat'][dataset['E_Heat']==file]

# %%
dataset['E_Heat'].replace(-4,21,inplace = True )

# %%
dataset.cov()

# %%
sn.heatmap(dataset.corr())

# %%
dataset.info()

# %%
new_col = pd.read_csv(r"C:\Users\BRAKAY\Desktop\data science\Data_New.csv")
new_col
# Out:
#     P/OffP
# 0   OffPeak
# 1   OffPeak
# 2   OffPeak
# 3   OffPeak
# 4   OffPeak
# 5   OffPeak
# 6      Peak
# 7      Peak
# 8      Peak
# 9   OffPeak
# 10  OffPeak
# 11  OffPeak
# 12  OffPeak
# 13  OffPeak
# 14  OffPeak
# 15  OffPeak
# 16     Peak
# 17     Peak
# 18     Peak
# 19     Peak
# 20     Peak
# 21  OffPeak
# 22  OffPeak
# 23  OffPeak

# %%
data_set = pd.concat([data,new_col], axis = 1)

# %%
data_set
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants  P/OffP
# 0      1    24.0      28    10          -15             12  OffPeak
# 1      2    17.0      32    12          -17             12  OffPeak
# 2      3    16.0      34    11          -19             12  OffPeak
# 3      3    16.0      34    11          -19             12  OffPeak
# 4      4    16.0      33    12          -18             12  OffPeak
# 5      5    16.0      30    10          -14             12  OffPeak
# 6      6    16.0      31    10          -16             12     Peak
# 7      7    19.0      28    14          -14             12     Peak
# 8      8    22.0      29    12          -15              9     Peak
# 9      9    25.0      26    12          -12              8  OffPeak
# 10    10    26.0      24    14           -8              8  OffPeak
# 11    11    27.0      20    14           -4              8  OffPeak
# 12    12    30.0      19    16            0              5  OffPeak
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
# Time             25 non-null int64
# E_Plug           25 non-null float64
# E_Heat           25 non-null int64
# Price            25 non-null object
# Temperature      25 non-null int64
# No. Occupants    25 non-null int64
# P/OffP           24 non-null object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.5+ KB

# %%
data_sets = pd.get_dummies(data_set)
data_sets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 18 columns):
# Time               25 non-null int64
# E_Plug             25 non-null float64
# E_Heat             25 non-null int64
# Temperature        25 non-null int64
# No. Occupants      25 non-null int64
# Price_!            25 non-null uint8
# Price_10           25 non-null uint8
# Price_11           25 non-null uint8
# Price_12           25 non-null uint8
# Price_14           25 non-null uint8
# Price_16           25 non-null uint8
# Price_17           25 non-null uint8
# Price_18           25 non-null uint8
# Price_20           25 non-null uint8
# Price_21           25 non-null uint8
# Price_22           25 non-null uint8
# P/OffP _OffPeak    25 non-null uint8
# P/OffP _Peak       25 non-null uint8
# dtypes: float64(1), int64(4), uint8(13)
# memory usage: 1.4 KB

# %%
from sklearn.preprocessing import minmax_scale,normalize

# %%
data_set
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants  P/OffP
# 0      1    24.0      28    10          -15             12  OffPeak
# 1      2    17.0      32    12          -17             12  OffPeak
# 2      3    16.0      34    11          -19             12  OffPeak
# 3      3    16.0      34    11          -19             12  OffPeak
# 4      4    16.0      33    12          -18             12  OffPeak
# 5      5    16.0      30    10          -14             12  OffPeak
# 6      6    16.0      31    10          -16             12     Peak
# 7      7    19.0      28    14          -14             12     Peak
# 8      8    22.0      29    12          -15              9     Peak
# 9      9    25.0      26    12          -12              8  OffPeak
# 10    10    26.0      24    14           -8              8  OffPeak
# 11    11    27.0      20    14           -4              8  OffPeak
# 12    12    30.0      19    16            0              5  OffPeak
# ...

# %%
data_set.replace({'!':21},inplace = True)

# %%
data_set
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants  P/OffP
# 0      1    24.0      28    10          -15             12  OffPeak
# 1      2    17.0      32    12          -17             12  OffPeak
# 2      3    16.0      34    11          -19             12  OffPeak
# 3      3    16.0      34    11          -19             12  OffPeak
# 4      4    16.0      33    12          -18             12  OffPeak
# 5      5    16.0      30    10          -14             12  OffPeak
# 6      6    16.0      31    10          -16             12     Peak
# 7      7    19.0      28    14          -14             12     Peak
# 8      8    22.0      29    12          -15              9     Peak
# 9      9    25.0      26    12          -12              8  OffPeak
# 10    10    26.0      24    14           -8              8  OffPeak
# 11    11    27.0      20    14           -4              8  OffPeak
# 12    12    30.0      19    16            0              5  OffPeak
# ...

# %%
data_set.fillna(method ='ffill',inplace = True)

# %%
data_set
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants  P/OffP
# 0      1    24.0      28    10          -15             12  OffPeak
# 1      2    17.0      32    12          -17             12  OffPeak
# 2      3    16.0      34    11          -19             12  OffPeak
# 3      3    16.0      34    11          -19             12  OffPeak
# 4      4    16.0      33    12          -18             12  OffPeak
# 5      5    16.0      30    10          -14             12  OffPeak
# 6      6    16.0      31    10          -16             12     Peak
# 7      7    19.0      28    14          -14             12     Peak
# 8      8    22.0      29    12          -15              9     Peak
# 9      9    25.0      26    12          -12              8  OffPeak
# 10    10    26.0      24    14           -8              8  OffPeak
# 11    11    27.0      20    14           -4              8  OffPeak
# 12    12    30.0      19    16            0              5  OffPeak
# ...

# %%
data_set.drop(['P/OffP'],axis =1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-ad3e55983790> in <module>
# ----> 1 data_set.drop(['P/OffP'],axis =1, inplace= True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0      1    24.0      28    10          -15             12
# 1      2    17.0      32    12          -17             12
# 2      3    16.0      34    11          -19             12
# 3      3    16.0      34    11          -19             12
# 4      4    16.0      33    12          -18             12
# 5      5    16.0      30    10          -14             12
# 6      6    16.0      31    10          -16             12
# 7      7    19.0      28    14          -14             12
# 8      8    22.0      29    12          -15              9
# 9      9    25.0      26    12          -12              8
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14     NaN      13    17            2              4
# ...

# %%
data.replace({'!':21},inplace = True)

# %%
data.fillna(method ='ffill',inplace = True)

# %%
data = data.drop('No. Occupants',axis =1)

# %%
data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature
# 0      1    24.0      28    10          -15
# 1      2    17.0      32    12          -17
# 2      3    16.0      34    11          -19
# 3      3    16.0      34    11          -19
# 4      4    16.0      33    12          -18
# 5      5    16.0      30    10          -14
# 6      6    16.0      31    10          -16
# 7      7    19.0      28    14          -14
# 8      8    22.0      29    12          -15
# 9      9    25.0      26    12          -12
# 10    10    26.0      24    14           -8
# 11    11    27.0      20    14           -4
# 12    12    30.0      19    16            0
# 13    13    30.0      19    16            0
# 14    14    30.0      13    17            2
# 15    15    27.0      14    17            3
# 16    16    27.0      16    17            2
# 17    17    28.0      -4    18            0
# 18    18    33.0      26    20           -6
# 19    19    42.0      32    21           -8
# ...

# %% [markdown]
# ##NORMALIZATION OF DATA SETS

# %%
# first method, minmax scale
from sklearn.preprocessing import minmax_scale, normalize

# %%
datas = minmax_scale(data,feature_range=(0,1))

# %%
datas
# Out:
# array([[0.        , 0.07692308, 0.8       , 0.        , 0.28      ,
#         1.        ],
#        [0.04347826, 0.00961538, 0.9       , 0.16666667, 0.2       ,
#         1.        ],
#        [0.08695652, 0.        , 0.95      , 0.08333333, 0.12      ,
#         1.        ],
#        [0.08695652, 0.        , 0.95      , 0.08333333, 0.12      ,
#         1.        ],
#        [0.13043478, 0.        , 0.925     , 0.16666667, 0.16      ,
#         1.        ],
#        [0.17391304, 0.        , 0.85      , 0.        , 0.32      ,
#         1.        ],
#        [0.2173913 , 0.        , 0.875     , 0.        , 0.24      ,
#         1.        ],
#        [0.26086957, 0.02884615, 0.8       , 0.33333333, 0.32      ,
#         1.        ],
#        [0.30434783, 0.05769231, 0.825     , 0.16666667, 0.28      ,
#         0.625     ],
#        [0.34782609, 0.08653846, 0.75      , 0.16666667, 0.4       ,
#         0.5       ],
#        [0.39130435, 0.09615385, 0.7       , 0.33333333, 0.56      ,
# ...

# %%
#second method is the normalize method 
data1 = normalize(data,norm = 'l2',axis = 0)
data1
# Out:
# array([[ 0.01427261,  0.13011045,  0.20345485,  0.12518596, -0.22761262],
#        [ 0.02854523,  0.09216157,  0.23251983,  0.15022315, -0.25796097],
#        [ 0.04281784,  0.0867403 ,  0.24705232,  0.13770456, -0.28830932],
#        [ 0.04281784,  0.0867403 ,  0.24705232,  0.13770456, -0.28830932],
#        [ 0.05709045,  0.0867403 ,  0.23978607,  0.15022315, -0.27313515],
#        [ 0.07136306,  0.0867403 ,  0.21798734,  0.12518596, -0.21243845],
#        [ 0.08563568,  0.0867403 ,  0.22525358,  0.12518596, -0.2427868 ],
#        [ 0.09990829,  0.10300411,  0.20345485,  0.17526035, -0.21243845],
#        [ 0.1141809 ,  0.11926791,  0.21072109,  0.15022315, -0.22761262],
#        [ 0.12845352,  0.13553172,  0.18892236,  0.15022315, -0.1820901 ],
#        [ 0.14272613,  0.14095299,  0.17438987,  0.17526035, -0.1213934 ],
#        [ 0.15699874,  0.14637425,  0.14532489,  0.17526035, -0.0606967 ],
#        [ 0.17127135,  0.16263806,  0.13805865,  0.20029754,  0.        ],
# ...

# %%
data1 = pd.DataFrame(data1,columns =['Time','E_Plug','E_Heat','Price','Temperature'])

# %%
data1
# Out:
#         Time    E_Plug    E_Heat     Price  Temperature
# 0   0.014273  0.130110  0.203455  0.125186    -0.227613
# 1   0.028545  0.092162  0.232520  0.150223    -0.257961
# 2   0.042818  0.086740  0.247052  0.137705    -0.288309
# 3   0.042818  0.086740  0.247052  0.137705    -0.288309
# 4   0.057090  0.086740  0.239786  0.150223    -0.273135
# 5   0.071363  0.086740  0.217987  0.125186    -0.212438
# 6   0.085636  0.086740  0.225254  0.125186    -0.242787
# 7   0.099908  0.103004  0.203455  0.175260    -0.212438
# 8   0.114181  0.119268  0.210721  0.150223    -0.227613
# 9   0.128454  0.135532  0.188922  0.150223    -0.182090
# 10  0.142726  0.140953  0.174390  0.175260    -0.121393
# 11  0.156999  0.146374  0.145325  0.175260    -0.060697
# 12  0.171271  0.162638  0.138059  0.200298     0.000000
# 13  0.185544  0.162638  0.138059  0.200298     0.000000
# 14  0.199817  0.162638  0.094461  0.212816     0.030348
# 15  0.214089  0.146374  0.101727  0.212816     0.045523
# ...

# %%
d = [2,5,12,13,15,32,41]
d.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-4c312b3715ab> in <module>
#       1 d = [2,5,12,13,15,32,41]
# ----> 2 d.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
m = np.median(d)
m
# Out:
# 13.0
